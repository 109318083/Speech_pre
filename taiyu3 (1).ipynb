# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.15 
# !pip install tensorflow-gpu==1.15
# Out:
# Uninstalling tensorflow-2.4.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.4.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.0
# ...
#      |████████████████████████████████| 412.3MB 40kB/s
# ...
#      |████████████████████████████████| 3.8MB 55.2MB/s
# ...
#      |████████████████████████████████| 512kB 45.9MB/s
# ...
#      |████████████████████████████████| 51kB 7.4MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=41ce378812166b09d4eeb1d5e60fa48b71a3b44db6343d0470fc3033fef4148e
# ...

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
# Out:
# 1.15.0
# True

# %%
#!unzip /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master.zip -d /home
#!unrar x /content/drive/MyDrive/taiyu3/test.rar -d /home/tensorflow-ctc-speech-recognition-master
#!unzip /content/drive/MyDrive/taiyu3/train.zip -d /home/tensorflow-ctc-speech-recognition-master
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2115.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2116.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2117.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2118.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2119.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_212.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2120.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2121.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2122.txt
#   inflating: /home/tensorflow-ctc-speech-recognition-master/train/txt/p225/p225_2123.txt
# ...

# %%
# %cd /home/tensorflow-ctc-speech-recognition-master
# Out:
# /home/tensorflow-ctc-speech-recognition-master

# %%
# !pip install python_speech_features fast_ctc_decode
# Out:
# ...
#      |████████████████████████████████| 368kB 9.1MB/s
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-cp36-none-any.whl size=5890 sha256=6facfa3de059a7722d42e0ee1a53d6472fa8bcaa5d50a92a66ee81efde76a37b
#   Stored in directory: /root/.cache/pip/wheels/3c/42/7c/f60e9d1b40015cd69b213ad90f7c18a9264cd745b9888134be
# Successfully built python-speech-features
# ...

# %%
# !python ctc_tensorflow_example16000fin002.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# - Original (training) : tsi si ka ti huah song e | loh hoo thinn honnh loo kut kut he han too luh tioh ai liah hoo an |  ...
# - Decoded  (training) : i si ka ti hua song      |  lo ho thi lo ku ku ahan tua lo ti a liahoa                        |  ...
# - Original (training) : na ho lin i au tioh ai tui gua it sim it i be tang koh khi tsiap kin pat lang | ooh ooh |  ...
# - Decoded  (training) : h lia tia t guai sim kii be tang ku khi tsa ki pa                             | o o     |  ...
# - Original (training) : kang tai gi ah bian khai tsinn a | sin sing e bu tshin pau iong e lu sing |  ...
# - Decoded  (training) : ng ta i bnh kha tsin a           | n sing e bu tsi pa iong e lu si        |  ...
# ...

# %%
# !cp -r /home/tensorflow-ctc-speech-recognition-master/model -d /content/drive/MyDrive/123
