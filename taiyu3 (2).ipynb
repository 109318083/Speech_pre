# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.15 
# !pip install tensorflow-gpu==1.15
# Out:
# Uninstalling tensorflow-2.4.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.4.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.0
# ...
#      |████████████████████████████████| 412.3MB 37kB/s
# ...
#      |████████████████████████████████| 3.8MB 51.2MB/s
# ...
#      |████████████████████████████████| 512kB 52.7MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=f0367dbbaede63ce93541d74586ffedfd7d77a6e2b3eb8b1a3d5a37bf15117fe
# ...

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
# Out:
# 1.15.0
# True

# %%
#!unzip /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master.zip -d /content/drive/MyDrive/taiyu3
#!unrar x /content/drive/MyDrive/taiyu3/test.rar -d /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master
#!unzip /content/drive/MyDrive/taiyu3/train.zip -d /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master

# %%
# %cd /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master
# Out:
# /content/drive/MyDrive/taiyu3/tensorflow-ctc-speech-recognition-master

# %%
# !pip install python_speech_features fast_ctc_decode
# Out:
# ...
#      |████████████████████████████████| 368kB 6.8MB/s
# ...

# %%
# !python ctc_tensorflow_example16000fin001.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# - Original (training) : ah li tsuan poo ka ting khi lai beh tui toh tshut lip | ko ni kiu si tsit khuan kai tshoo pun e un tong |  ...
# - Decoded  (training) : ah li tsuan poo ka ting khi lai beh tui toh tshut lit | ko ni kiu si tsit khuan kai tshoo pun e un tong |  ...
# - Original (training) : js to si javascript a ka li kong li long be ki tsit ah | tui oh im gak e lang lai kong e hiau puann phi a nooh si kai ki pun e tai tsi |  ...
# - Decoded  (training) : js to si jiavascri a ka li kong li long be ki tsit ah  | tui oh im gak e lang lai kong  hiau puann phi a nooh si kai ki pun e tai tsi  |  ...
# - Original (validation) : m | eh |  ...
# - Decoded  (validation) : m | eh |  ...
# --------------------------------------------------------------------------------
# Epoch 1286/10000, train_cost = 0.894, train_ler = 0.004, val_cost = 2.792, val_ler = 0.219, time = 16.020
# save model to model/ctc-5615-1287
# ...
