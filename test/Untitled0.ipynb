# %%
! /opt/bin/nvidia-smi
# Out:
# Thu Jan 14 18:04:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.15 
# !pip install tensorflow-gpu==1.15
# Out:
# Uninstalling tensorflow-2.4.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.6/dist-packages/tensorflow-2.4.0.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.0
# ...
#      |████████████████████████████████| 412.3MB 41kB/s
# ...
#      |████████████████████████████████| 51kB 8.5MB/s
# ...
#      |████████████████████████████████| 3.8MB 53.6MB/s
# ...
#      |████████████████████████████████| 512kB 49.0MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=d2a0dd7d31cd8713c163a89c9884226482bc7e7eb0a058b3e84bc607078fca16
# ...

# %%
import tensorflow as tf
print(tf.__version__)
print(tf.test.is_gpu_available())
# Out:
# 1.15.0
# True

# %%
# !pip install python_speech_features fast_ctc_decode
# Out:
# ...
#      |████████████████████████████████| 368kB 15.1MB/s
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-cp36-none-any.whl size=5890 sha256=c28c36e8d7a1532cd8bf375c9f8e9885445b37e67900c5e9af806784fa9492ff
#   Stored in directory: /root/.cache/pip/wheels/3c/42/7c/f60e9d1b40015cd69b213ad90f7c18a9264cd745b9888134be
# Successfully built python-speech-features
# ...

# %%
#!unrar x /content/drive/MyDrive/taiyu3/test.rar -d /content/drive/MyDrive/taiyu3test

# %%
# %cd /content/drive/MyDrive/taiyu3test/
# Out:
# /content/drive/MyDrive/taiyu3test

# %%
# !python testfile_beta012.py
# Out:
# WARNING:tensorflow:From testfile_beta012.py:14: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From testfile_beta012.py:14: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Initializing AudioReader()
# audio_dir = test
# cache_dir = cache_test
# sample_rate = 16000
# speakers_sub_list = None
# Using the generated files at cache_test. Using them to load the cache. Be sure to have enough memory.
# Cache took 0.45 seconds to load. 346 keys.
# tse hoo tsan se kai ling pang kah tik lin khuann tsai kan lai u put li e yng hiong
# ing ahm  kua tsiah kah li leh lo
# ah beh siann poo
# si sit giam poo soo
# ah sui kam moo a ai tsok li the i tshing ka
# an ne lah
# lin kianm bo kong iau u si gih jit tsiu siu kuai si kau mah gua ka lin konggia ba khuann hng i king siok thang kua lah
# ah san a pah me kue ah
# kiam piann tsiah kah khauh khan kio
# ...

# %%
import csv

# %%
with open('pre.txt', 'r') as in_file:
        stripped = (line.strip() for line in in_file)
        lines = (line.split(",") for line in stripped if line)
        with open('pre.csv','w') as out_file:
            writer = csv.writer(out_file)
            writer.writerow(['text'])
            writer.writerows(lines)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pre.csv')
df.index = np.arange(1, len(df) + 1)
df.index.names = ['id']
df.to_csv('CTC_result010.csv')
